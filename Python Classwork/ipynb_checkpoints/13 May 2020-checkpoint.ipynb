# %%
x=Aditya
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-46cb65456f7c> in <module>
# ----> 1 x=Aditya
#
# NameError: name 'Aditya' is not defined

# %%
x='Aditya'

# %%
print(x.upper())
# Out:
# ADITYA

# %%
x
# Out:
# 'Aditya'

# %%
num_list=[1, 4, 6, 3, 7, 3]

# %%
num_list[2]
# Out:
# 6

# %%
num_list[:3]
# Out:
# [1, 4, 6]

# %%
num_list[2:5:2]
# Out:
# [6, 7]

# %%
num_list.count(3)
# Out:
# 2

# %%
num_list.sort()
